# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehab-Salah/Library-System/blob/master/yolov5GP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/drive/MyDrive/dataset/Dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Dataset/train/Coffee cup_Footwear_Chair_Bed_Spoon_Bottle_Door_Toilet_Towel/407a21269a350e0f.txt
#   inflating: Dataset/train/Coffee cup_Footwear_Chair_Bed_Spoon_Bottle_Door_Toilet_Towel/0f9c27c1af510063.txt
#   inflating: Dataset/train/Coffee cup_Footwear_Chair_Bed_Spoon_Bottle_Door_Toilet_Towel/f1bcaf457f0268ce.txt
#   inflating: Dataset/train/Coffee cup_Footwear_Chair_Bed_Spoon_Bottle_Door_Toilet_Towel/dfaabf83f2b9b5e9.txt
#   inflating: Dataset/train/Coffee cup_Footwear_Chair_Bed_Spoon_Bottle_Door_Toilet_Towel/54561ecc6fd61aeb.txt
#   inflating: Dataset/train/Coffee cup_Footwear_Chair_Bed_Spoon_Bottle_Door_Toilet_Towel/d51b33645b8d0395.txt
#   inflating: Dataset/train/Coffee cup_Footwear_Chair_Bed_Spoon_Bottle_Door_Toilet_Towel/79977fcd31cfb056.txt
#   inflating: Dataset/train/Coffee cup_Footwear_Chair_Bed_Spoon_Bottle_Door_Toilet_Towel/493b8a1bd7ccd437.txt
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-1-g66aaf51 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 51.8/78.2 GB disk)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# ...
# detect: weights=['yolov5s.pt'], source=data/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-100-g5185981 torch 1.10.0+cu111 CPU
#
# ...
# 100% 14.0M/14.0M [00:00<00:00, 58.3MB/s]
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, Done. (0.366s)
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 1 tie, Done. (0.287s)
# Speed: 1.3ms pre-process, 326.8ms inference, 7.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 48 --epochs 200 --data coco128.yaml --weights /content/drive/MyDrive/weights/newweights/runs/train/exp4/weights/last.pt --rect --multi-scale --noval --freeze 20
# Out:
# ...
# train: weights=/content/drive/MyDrive/weights/newweights/runs/train/exp4/weights/last.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=48, imgsz=640, rect=True, resume=False, nosave=False, noval=True, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=True, single_cls=False, optimizer=AdamW, sync_bn=False, workers=8, project=/content/drive/MyDrive/weights/newweights/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[20], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-1-g66aaf51 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --weights /content/gdrive/MyDrive/weights2/runs/train/exp15/weights/last.pt --img 640 --conf 0.20 --source /content/Dataset/shoes11.jpeg
# Out:
# detect: weights=['/content/gdrive/MyDrive/weights2/runs/train/exp15/weights/last.pt'], source=/content/Dataset/shoes11.jpeg, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/gdrive/MyDrive/weights2/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-110-gfcd180d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1771342 parameters, 0 gradients, 4.2 GFLOPs
# image 1/1 /content/Dataset/shoes11.jpeg: 640x480 1 Shoes, Done. (0.021s)
# Speed: 0.6ms pre-process, 21.0ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content/gdrive/MyDrive/weights2/runs/detect/exp3
